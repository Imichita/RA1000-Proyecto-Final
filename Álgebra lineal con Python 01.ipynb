# %% [markdown]
# #Introducción a Python
# 1. Objetos: números, strings, listas, arreglos (Vectores / matrices) , diccionarios (crear bases de datos), DataFrames.
# 2. Atributos de objetos.
# 3.

# %% [markdown]
# ##Sistema de ecuaciones lineales

# %% [markdown]
# Hay funciones (built-in) dentro de Python:
# * +, -, *, $**$, etcetera.
# * `type` (contesta a la pregunta, ¿Qué tipo de objeto estás representando?), `print` (Imprimir el código)

# %%
5+2, 5-2, 5*2, 5**2
# Out:
# (7, 3, 10, 25)

# %%
print (5*2)
print (5+2)
print (5**2)
# Out:
# 10
# 7
# 25

# %%
print("hola mundo")
# Out:
# hola mundo

# %%
type("hola mundo")
# Out:
# str

# %%
type(1.144678)
# Out:
# float

# %% [markdown]
# Una variable es una forma de nombrar y guardar a un objeto

# %%
#Creando dos variables que son int

x = 1.98
y = 0.32

# %%
#De esta forma podemos realizar las operaciones antes dadas
print(f"Las operaciones anteriores son: {x+y}, {x-y}, {x**y}")
# Out:
# Las operaciones anteriores son: 2.3, 1.66, 1.2443222327371004

# %%
type(2), type(2.1), type ("2") #type nos dice el tipo de objeto que se está utilizando
# Out:
# (int, float, str)

# %% [markdown]
# ##Nombre = texto
# Debug =print(variable)

# %%
variable = "Hola"
x=5
Cesar = {1,2,"perro"}

# %%
print(variable)
print(x)
# Out:
# Hola
# 5
